# %% [markdown]
# # SPx — Spectral Processing
#
# This notebook runs the **processing** stage of the [SPx](https://github.com/mineralogy-rocks/SPx) pipeline: read CSV spectral files, filter by wavelength thresholds, extract convex-hull quotient features, and generate statistics and plots.
#
# > **Note:** The first code cell installs SPx directly from GitHub. No runtime restart is needed.
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mineralogy-rocks/SPx/blob/main/notebooks/processing.ipynb)

# %%
# !pip install "SPx[notebook] @ git+https://github.com/mineralogy-rocks/SPx.git"

# %%
# %matplotlib inline

import logging

from src.config import settings
from src.base.main import run_pipeline

logging.basicConfig(level=logging.INFO, format="%(asctime)s %(levelname)s %(message)s")

# %% [markdown]
# ## Data Setup
#
# Upload your CSV spectral files to the `input/` folder (created below).
#
# Need sample data? Download from the [sample files on GitHub](https://github.com/mineralogy-rocks/SPx/tree/main/data/samples).

# %%
import os

INPUT_FOLDER = "input"
OUTPUT_FOLDER = "output"

os.makedirs(INPUT_FOLDER, exist_ok=True)
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

settings.configure(".", INPUT_FOLDER, OUTPUT_FOLDER)

# %% [markdown]
# ### Upload Files (Colab)
#
# If running in Google Colab, uncomment the cell below to upload your CSV files interactively.

# %%
# from google.colab import files
# uploaded = files.upload()
# for name, data in uploaded.items():
#     with open(os.path.join(INPUT_FOLDER, name), "wb") as f:
#         f.write(data)

# %% [markdown]
# ## Thresholds
#
# Spectral peak wavelength ranges (nm) used to filter input data. Edit the list below to customize.
#
# | Peak | Range (nm) |
# |------|------------|
# | peak-1 | 5500 – 8000 |
# | peak-2 | 4600 – 5540 |
# | peak-3 | 4310 – 4788 |

# %%
thresholds = [
    ("peak-1", (5500, 8000)),
    ("peak-2", (4600, 5540)),
    ("peak-3", (4310, 4788)),
]

# %%
run_pipeline(show_plots=False, thresholds=thresholds)

# %% [markdown]
# ## Results
#
# Load and display the processing results from `results.xlsx`.

# %%
import pandas as pd

results_path = settings.OUTPUT_PATH / "data" / "results.xlsx"

if results_path.exists():
    display(pd.read_excel(results_path))
else:
    print(f"No results found at {results_path}")
